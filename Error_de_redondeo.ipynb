# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/metodos_numericos/blob/main/Error_de_redondeo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1: Error de redondeo en Python

# %%
# Definir los valores de a y b, En el caso de a hacer la suma
a = 0.1 + 0.2
b = 0.3

#imprimir el resultado del valor de a
print(a)
# Verificar si es verdadero o falso
print(a == b)
#imprimir la operacion pero en resta
print(abs(a - b))
# Out:
# 0.30000000000000004
# False
# 5.551115123125783e-17

# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/metodos_numericos/blob/main/Error_truncameinto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ERROR DE TRUNCAMIENTO
import math
#valor donde se evaluara la funcion
x = 1
#Aproximacion usando los primeros 3 términos de la serie
aprox = 1 + x + (x**2)/2
# Valor real usando la función exponencial
real = math.exp(x)

#calculo del error
error = abs(real - aprox)

print("Aprox:", aprox)
print("Real:", real)
print("Error:", error)
# Out:
# Aprox: 2.5
# Real: 2.718281828459045
# Error: 0.2182818284590451

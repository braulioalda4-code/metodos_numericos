# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/metodos_numericos/blob/main/Cifras_significativas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1 Cifras significativas y redondeo

# %%
# Importar la libreria
import numpy as np

# Definir la x
x=3.1415926535

#Imprimir los x y hacer comparacio con diferentes valores
print(round(x, 2))
print(round(x, 4))
print(round(x, 6))
# Out:
# 3.14
# 3.1416
# 3.141593
